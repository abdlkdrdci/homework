# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio </h1>

# %% [markdown]
# <b>Abdulkadir</b>
#
# data analyst

# %% [markdown]
# <i>I am interested in data science because it is sexy job.</i>

# %% [markdown]
# <h3>in cell 5 I wanted to sum some of the numbers.</h3>

# %%
print(2+3-1)
# Out:
# 4

# %% [markdown]
# <ol>
# <li>Fish</li>
# <li>Eggs</li>
# <li>Cheese</li>
# </ol>
#
# <a> href="https://www.google.com" >Link to Google</a>
#
#
# <hr>
